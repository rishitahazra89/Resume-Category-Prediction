# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('UpdatedResumeDataset.csv')

# %%
df.head()
# Out:
#        Category                                             Resume
# 0  Data Science  Skills * Programming Languages: Python (pandas...
# 1  Data Science  Education Details \r\nMay 2013 to May 2017 B.E...
# 2  Data Science  Areas of Interest Deep Learning, Control Syste...
# 3  Data Science  Skills â¢ R â¢ Python â¢ SAP HANA â¢ Table...
# 4  Data Science  Education Details \r\n MCA   YMCAUST,  Faridab...

# %%
df.shape
# Out:
# (962, 2)

# %%
df['Category'].value_counts()
# Out:
# Category
# Java Developer               84
# Testing                      70
# DevOps Engineer              55
# Python Developer             48
# Web Designing                45
# HR                           44
# Hadoop                       42
# Blockchain                   40
# ETL Developer                40
# Operations Manager           40
# Data Science                 40
# Sales                        40
# Mechanical Engineer          40
# Arts                         36
# Database                     33
# Electrical Engineering       30
# Health and fitness           30
# PMO                          30
# Business Analyst             28
# DotNet Developer             28
# Automation Testing           26
# Network Security Engineer    25
# SAP Developer                24
# Civil Engineer               24
# Advocate                     20
# Name: count, dtype: int64

# %%
plt.figure(figsize=(15,5))

sns.countplot(df['Category']) 

plt.xticks(rotation=90)

plt.show()

# %%
plt.figure(figsize=(15, 5))

# Use a color palette with different colors
sns.countplot(data=df, x='Category', palette='husl')  # You can try 'Set2', 'husl', 'coolwarm', etc.

plt.xticks(rotation=90)
plt.show()
# Out:
# C:\Users\hazra\AppData\Local\Temp\ipykernel_16980\2508271703.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x='Category', palette='husl')  # You can try 'Set2', 'husl', 'coolwarm', etc.

# %%
df['Category'].unique()
# Out:
# array(['Data Science', 'HR', 'Advocate', 'Arts', 'Web Designing',
#        'Mechanical Engineer', 'Sales', 'Health and fitness',
#        'Civil Engineer', 'Java Developer', 'Business Analyst',
#        'SAP Developer', 'Automation Testing', 'Electrical Engineering',
#        'Operations Manager', 'Python Developer', 'DevOps Engineer',
#        'Network Security Engineer', 'PMO', 'Database', 'Hadoop',
#        'ETL Developer', 'DotNet Developer', 'Blockchain', 'Testing'],
#       dtype=object)

# %%
counts = df['Category'].value_counts()

labels = df['Category'].unique()
plt.figure(figsize=(15,10))

plt.pie(counts, labels=labels)
# Out:
# ([<matplotlib.patches.Wedge at 0x23a9f40ffb0>,
# ...
#  [Text(1.058871228953308, 0.29797939609125923, 'Data Science'),
#   Text(0.7841417468169058, 0.7714413269322118, 'HR'),
#   Text(0.4134731563409379, 1.0193330903024107, 'Advocate'),
#   Text(0.053862331076050214, 1.098680503736666, 'Arts'),
#   Text(-0.2771758554020645, 1.0645062447830609, 'Web Designing'),
#   Text(-0.5706079161115722, 0.9404289479119671, 'Mechanical Engineer'),
#   Text(-0.8089120262381768, 0.7454269473310228, 'Sales'),
#   Text(-0.9773196261993998, 0.5048230860860717, 'Health and fitness'),
#   Text(-1.0745482070561094, 0.23525762625789806, 'Civil Engineer'),
#   Text(-1.0988505454600117, -0.05027403646252011, 'Java Developer'),
#   Text(-1.0485773173407904, -0.3323937567981556, 'Business Analyst'),
#   Text(-0.9271404102234844, -0.5919549473825093, 'SAP Developer'),
#   Text(-0.7427813690411197, -0.811341998053472, 'Automation Testing'),
#   Text(-0.5207132389301881, -0.9689467079271352, 'Electrical Engineering'),
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.head()
df.columns
# Out:
# Index(['Category', 'Resume'], dtype='object')

# %%
df['Category'][0]
# Out:
# 'Data Science'

# %%
df['Resume'][0]
# Out:
# 'Skills * Programming Languages: Python (pandas, numpy, scipy, scikit-learn, matplotlib), Sql, Java, JavaScript/JQuery. * Machine learning: Regression, SVM, NaÃ¯ve Bayes, KNN, Random Forest, Decision Trees, Boosting techniques, Cluster Analysis, Word Embedding, Sentiment Analysis, Natural Language processing, Dimensionality reduction, Topic Modelling (LDA, NMF), PCA & Neural Nets. * Database Visualizations: Mysql, SqlServer, Cassandra, Hbase, ElasticSearch D3.js, DC.js, Plotly, kibana, matplotlib, ggplot, Tableau. * Others: Regular Expression, HTML, CSS, Angular 6, Logstash, Kafka, Python Flask, Git, Docker, computer vision - Open CV and understanding of Deep learning.Education Details \r\n\r\nData Science Assurance Associate \r\n\r\nData Science Assurance Associate - Ernst & Young LLP\r\nSkill Details \r\nJAVASCRIPT- Exprience - 24 months\r\njQuery- Exprience - 24 months\r\nPython- Exprience - 24 monthsCompany Details \r\ncompany - Ernst & Young LLP\r\ndescription - Fraud Investigat
# ...

# %%
import re

def cleanResume(txt):
    cleanText = re.sub(r'http\S+\s*', '', txt)
    cleanText = re.sub(r'RT|cc', '', cleanText)
    cleanText = re.sub(r'#\S+', '', cleanText)
    cleanText = re.sub(r'@\S+', '', cleanText)
    cleanText = re.sub(r'[%s]' % re.escape("""!"#$%&'()*+,-./:;<=>?@[\\]^_`{|}~"""), '', cleanText)
    cleanText = re.sub(r'[^\x00-\x7f]', '', cleanText)
    cleanText = re.sub(r'\s+', ' ', cleanText)
    return cleanText

# %%
cleanResume("my #### $ # #noorsaeed webiste like is this http://heloword and access it @gmain.com")
# Out:
# 'my webiste like is this and aess it '

# %%
df['Resume'] = df['Resume'].apply(lambda x: cleanResume(x))

# %%
df['Resume'][0]
# Out:
# 'Skills Programming Languages Python pandas numpy scipy scikitlearn matplotlib Sql Java JavaScriptJQuery Machine learning Regression SVM Nave Bayes KNN Random Forest Decision Trees Boosting techniques Cluster Analysis Word Embedding Sentiment Analysis Natural Language processing Dimensionality reduction Topic Modelling LDA NMF PCA Neural Nets Database Visualizations Mysql SqlServer Cassandra Hbase ElasticSearch D3js DCjs Plotly kibana matplotlib ggplot Tableau Others Regular Expression HTML CSS Angular 6 Logstash Kafka Python Flask Git Docker computer vision Open CV and understanding of Deep learningEducation Details Data Science Assurance Associate Data Science Assurance Associate Ernst Young LLP Skill Details JAVASCRIPT Exprience 24 months jQuery Exprience 24 months Python Exprience 24 monthsCompany Details company Ernst Young LLP description Fraud Investigations and Dispute Services Assurance TECHNOLOGY ASSISTED REVIEW TAR Technology Assisted Review assists in aelerating the revie
# ...

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()

# %%
le.fit(df['Category'])

df['Category'] = le.transform(df['Category'])

# %%
df
# Out:
#      Category                                             Resume
# 0           6  Skills Programming Languages Python pandas num...
# 1           6  Education Details May 2013 to May 2017 BE UITR...
# 2           6  Areas of Interest Deep Learning Control System...
# 3           6  Skills R Python SAP HANA Tableau SAP HANA SQL ...
# 4           6  Education Details MCA YMCAUST Faridabad Haryan...
# ..        ...                                                ...
# 957        23  Computer Skills Proficient in MS office Word B...
# 958        23   Willingness to aept the challenges Positive t...
# 959        23  PERSONAL SKILLS Quick learner Eagerness to lea...
# 960        23  COMPUTER SKILLS SOFTWARE KNOWLEDGE MSPower Poi...
# 961        23  Skill Set OS Windows XP788110 Database MYSQL s...
#
# [962 rows x 2 columns]

# %%
df.Category.unique()
# Out:
# array([ 6, 12,  0,  1, 24, 16, 22, 14,  5, 15,  4, 21,  2, 11, 18, 20,  8,
#        17, 19,  7, 13, 10,  9,  3, 23])

# %%
from sklearn.feature_extraction.text import TfidfVectorizer 
tfidf = TfidfVectorizer(stop_words='english')

tfidf.fit(df['Resume'])

requredTaxt = tfidf.transform(df['Resume'])

# %%
df
# Out:
#      Category                                             Resume
# 0           6  Skills Programming Languages Python pandas num...
# 1           6  Education Details May 2013 to May 2017 BE UITR...
# 2           6  Areas of Interest Deep Learning Control System...
# 3           6  Skills R Python SAP HANA Tableau SAP HANA SQL ...
# 4           6  Education Details MCA YMCAUST Faridabad Haryan...
# ..        ...                                                ...
# 957        23  Computer Skills Proficient in MS office Word B...
# 958        23   Willingness to aept the challenges Positive t...
# 959        23  PERSONAL SKILLS Quick learner Eagerness to lea...
# 960        23  COMPUTER SKILLS SOFTWARE KNOWLEDGE MSPower Poi...
# 961        23  Skill Set OS Windows XP788110 Database MYSQL s...
#
# [962 rows x 2 columns]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(requredTaxt, df['Category'], test_size=0.2,random_state=42)

# %%
x_train.shape
# Out:
# (769, 7898)

# %%
x_test.shape
# Out:
# (193, 7898)

# %%
from sklearn.neighbors import KNeighborsClassifier

from sklearn.multiclass import OneVsRestClassifier

from sklearn.metrics import accuracy_score

clf = OneVsRestClassifier (KNeighborsClassifier())

clf.fit(x_train,y_train)

ypred = clf.predict(x_test)

print(accuracy_score(y_test, ypred))
# Out:
# 0.9844559585492227

# %%
myresume="""Rishita Hazra
 534 234/E/1 S.S Bose Sarani
 Baidyabati M  – 712222
 hazrarishita09@gmail.com
 Linkedln:https://www.linkedin.com/in/
 +91 – 9674373470 
Date of Birth- 21th Jan, 2005 
Nationality-Indian 
Permanent Address-S.S.Bose Sarani Baidyabati,Hooghly 
Languages known: English ,  Bengali  ,Hindi
 Motivated, flexible and smart-working professional with continuous practices. Able to learn
 new ideas  quickly and able to act on them timely, good in managing time and meeting deadlines.
 Enthusiastic and detail-oriented Computer Science Engineering(AIML) student with expertise in
 Python, C , CSS  and HTML , along with experience in web  developing applications.                                     
B.Tech, Computer Science(AIML)
 Brainware University
 Baidyabati Surendranath Roy Balika Vidyalaya 
HSC
 71%
 Baidyabati Surendranath Roy Balika Vidyalaya
 SSC
 59.29%
 2022- 2026
 Currently Pursuing
 2022
 2020
 Programming Languages – C, C++, Java ,Python
 Frontend– HTML, CSS, JavaScript
 Database-SQL,MySQL
 Tools - DSA,Git,Github,Vs Code
 Tic-Tac-Toe game(HTML,CSS,JS)               
This game allows a human player to play against a computer AI, which uses the Minimax
 algorithm to make optimal moves
 AI-Based Animal Classifire(python)
 Implementing a deep learning-based classifier to distinguish between cates and dog.
2
 10 -day Intel Industrial training on AIML& Certification by
 INTEL(by Edgate Techonology)
 Certificate of Deep Learning (Infosys Springboard 5.0)
 Jan-Feb’25
 Aug’24
 A grid of cards, each hiding a symbol or image. 
The player flips two cards at a time to try to find a matching pair.
 If the cards match, they stay visible; if not, they flip back 
The game ends when all pairs are matched. 
                                 
Memory Card game(HTML.CSS.JS) 
Signature Date: 
Yoga
 Painting/Drawing.
 Dancing.
 Playing Flut
 github Link:https://github.com/rishitahazra8"""

# %%
import pickle
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.naive_bayes import MultinomialNB  # or whichever model you use

# %%
# Sample text data
texts = ["this is good", "this is bad", "I love it", "I hate it"]

# Create and fit TF-IDF
tfidf = TfidfVectorizer()
X = tfidf.fit_transform(texts)

# %%
# Sample labels (you can replace with your own)
y = [1, 0, 1, 0]

# Train classifier
clf = MultinomialNB()
clf.fit(X, y)
# Out:
# MultinomialNB()

# %%
# Save tfidf vectorizer
with open('tfidf.pkl', 'wb') as f:
    pickle.dump(tfidf, f)

# Save classifier
with open('clf.pkl', 'wb') as f:
    pickle.dump(clf, f)

# %%
# Load tfidf
with open('tfidf.pkl', 'rb') as f:
    tfidf = pickle.load(f)

# Load classifier
with open('clf.pkl', 'rb') as f:
    clf = pickle.load(f)
